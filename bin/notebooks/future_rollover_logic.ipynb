# %%
import pandas as pd
import numpy as npp
import yfinance as yf

# %%
import requests

# %%
import datetime

# %%
# Downlaod the latest data
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/130.0.0.0 Safari/537.36'
}

response = requests.get("https://www.niftyindices.com/IndexConstituent/ind_nifty50list.csv", headers=headers)
if response.status_code == 200:
    with open(r'.\data\n50.csv', 'wb') as f:
        f.write(response.content)
    print("Download successful")
else:
    print("Failed to download:", response.status_code)
# Out:
# Download successful

# %%
n50 = pd.read_csv(r'.\data\n50.csv')

# %%
yf.Ticker('BAJAJ-AUTO.NS').info
# Out:
# {'address1': 'Mumbai-Pune Road',
#  'address2': 'Akurdi',
#  'city': 'Pune',
#  'zip': '411035',
#  'country': 'India',
#  'phone': '91 20 6610 7868',
#  'fax': '91 20 2740 7380',
#  'website': 'https://www.bajajauto.com',
#  'industry': 'Auto Manufacturers',
#  'industryKey': 'auto-manufacturers',
#  'industryDisp': 'Auto Manufacturers',
#  'sector': 'Consumer Cyclical',
#  'sectorKey': 'consumer-cyclical',
#  'sectorDisp': 'Consumer Cyclical',
#  'longBusinessSummary': 'Bajaj Auto Limited, together with its subsidiaries, engages in the development, manufacture, and distribution of automobiles in India and internationally. The company offers motorcycles, bikes, commercial vehicles, electric two-wheelers, and three-wheeler, as well as related parts. It also exports its products. The company was founded in 1945 and is based in Pune, India.',
#  'fullTimeEmployees': 6192,
#  'companyOfficers': [{'maxAge': 1,
#    'name': 'Mr. Rajivnayan Rahulkumar Bajaj',
#    'age': 53,
# ...

# %%
tcs = yf.Ticker('TCS.NS')

# %%
N50=pd.read_csv("https://www.niftyindices.com/IndexConstituent/ind_nifty50list.csv")
# Out:
# ---------------------------------------------------------------------------
# RemoteDisconnected                        Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 N50=pd.read_csv("https://www.niftyindices.com/IndexConstituent/ind_nifty50list.csv")
#
# File d:\Miniconda\envs\sat_b\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
tcs.info
# Out:
# {'address1': 'TCS House',
#  'address2': 'Raveline Street Corner of Hazarimal Somani Marg Near Sterling Cinema, Fort',
#  'city': 'Mumbai',
#  'zip': '400 001',
#  'country': 'India',
#  'phone': '91 22 6778 9999',
#  'fax': '91 22 6778 9000',
#  'website': 'https://www.tcs.com',
#  'industry': 'Information Technology Services',
#  'industryKey': 'information-technology-services',
#  'industryDisp': 'Information Technology Services',
#  'sector': 'Technology',
#  'sectorKey': 'technology',
#  'sectorDisp': 'Technology',
# ...

# %%
tcs.history(period = "max",interval="1m")
# Out:
#                                   Open         High          Low        Close  \
# Datetime
# 2024-10-21 09:15:00+05:30  4131.750000  4137.950195  4124.299805  4126.750000
# 2024-10-21 09:16:00+05:30  4128.549805  4128.750000  4121.649902  4125.149902
# 2024-10-21 09:17:00+05:30  4126.149902  4126.149902  4116.299805  4118.000000
# 2024-10-21 09:18:00+05:30  4119.450195  4125.649902  4117.450195  4119.100098
# 2024-10-21 09:19:00+05:30  4119.100098  4122.399902  4117.149902  4119.649902
# ...                                ...          ...          ...          ...
# 2024-10-25 15:25:00+05:30  4058.000000  4060.199951  4058.000000  4058.949951
# 2024-10-25 15:26:00+05:30  4058.600098  4060.100098  4057.850098  4059.050049
# 2024-10-25 15:27:00+05:30  4058.750000  4059.500000  4056.100098  4059.000000
# 2024-10-25 15:28:00+05:30  4059.699951  4062.000000  4059.149902  4061.600098
# 2024-10-25 15:29:00+05:30  4060.000000  4062.000000  4060.000000  4060.000000
#
# ...

# %%
tcs.dividends
# Out:
# Series([], Name: Dividends, dtype: float64)

# %%
start_date = datetime.date(2024,1,1)

# %%
end_date = datetime.date.today()

# %%
scripts = yf.download(['TCS.NS','RELIANCE.NS'],start=start_date,end=end_date,period='1mo',group_by='ticker')
# Out:
# [*********************100%***********************]  2 of 2 completed

# %%
scripts['RELIANCE.NS'].reset_index()
# Out:
# Price                      Date         Open         High          Low  \
# 0     2024-01-01 00:00:00+00:00  2580.550049  2606.850098  2573.149902
# 1     2024-01-02 00:00:00+00:00  2585.000000  2615.000000  2573.000000
# 2     2024-01-03 00:00:00+00:00  2610.000000  2634.000000  2577.199951
# 3     2024-01-04 00:00:00+00:00  2588.000000  2609.850098  2579.100098
# 4     2024-01-05 00:00:00+00:00  2602.899902  2619.850098  2598.000000
# ..                          ...          ...          ...          ...
# 196   2024-10-18 00:00:00+00:00  2704.350098  2736.850098  2682.649902
# 197   2024-10-21 00:00:00+00:00  2734.250000  2748.000000  2715.449951
# 198   2024-10-22 00:00:00+00:00  2738.399902  2752.000000  2680.449951
# 199   2024-10-23 00:00:00+00:00  2675.000000  2714.949951  2670.000000
# 200   2024-10-24 00:00:00+00:00  2670.550049  2687.399902  2646.250000
#
# Price        Close    Adj Close    Volume
# 0      2590.250000  2581.488525   2015270
# ...

# %%
yf.download('TCS.NS RELIANCE.NS',start=start_date,end=end_date,period='1mo')['Close']
# Out:
# [*********************100%***********************]  2 of 2 completed
# Ticker                     RELIANCE.NS       TCS.NS
# Date
# 2024-01-01 00:00:00+00:00  2590.250000  3811.100098
# 2024-01-02 00:00:00+00:00  2611.699951  3783.199951
# 2024-01-03 00:00:00+00:00  2583.300049  3691.750000
# 2024-01-04 00:00:00+00:00  2596.649902  3666.800049
# 2024-01-05 00:00:00+00:00  2607.699951  3737.899902
# ...                                ...          ...
# 2024-10-18 00:00:00+00:00  2718.600098  4123.049805
# 2024-10-21 00:00:00+00:00  2738.399902  4079.850098
# 2024-10-22 00:00:00+00:00  2686.699951  4015.500000
# 2024-10-23 00:00:00+00:00  2677.050049  4066.250000
# 2024-10-24 00:00:00+00:00  2679.600098  4047.899902
#
# [201 rows x 2 columns]
